# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Dataset .csv')

# %%
aggregates_rating = df['Aggregate rating']
rating_counts = aggregates_rating.value_counts().sort_index()

# %%
most_common_rating_range = rating_counts.idxmax()

print('Most common rating range:',most_common_rating_range )
# Out:
# Most common rating range: 0.0

# %%
average_votes = df['Votes'].mean()

print("Average number of votes recieved by restaurants:", average_votes)
# Out:
# Average number of votes recieved by restaurants: 156.909747670401

# %%
plt.hist(aggregates_rating, bins=20, edgecolor= 'black')
plt.xlabel('Aggregate Rating')
plt.ylabel('Frequency')
plt.title('Distribution of Aggregates Rating')
plt.show()
